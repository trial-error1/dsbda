# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Amazonbookreviews.csv')

# %%
df.head()
# Out:
#        reviewerID      asin reviewername  helpful  \
# 0  A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1  A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2  A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3  A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4  A1SUAM1J3GNN3B     123.0      PRANOTI        3
#
#                                         reviewerText  overallRating  \
# 0  I bought this for my husband who plays the pia...            4.0
# 1                                  good book to read            3.0
# 2                                          high cost            2.5
# 3                                    good useof book            2.2
# 4                            I m happy with the book            3.0
#
#             Summary  UnixreviewTime  reviewTime
# 0       SUBWAY SURF             NaN         NaN
# 1            PILOT              NaN         NaN
# 2   DRIVE IN HEAVEN             NaN         NaN
# 3     SPORTS HEAVEN             NaN         NaN
# 4  HEAVEN OF PEARLS             NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 9 columns):
# reviewerID        43 non-null object
# asin              43 non-null float64
# reviewername      44 non-null object
# helpful           45 non-null int64
# reviewerText      45 non-null object
# overallRating     45 non-null float64
# Summary           45 non-null object
# UnixreviewTime    0 non-null float64
# reviewTime        0 non-null float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 2.5+ KB

# %%
df.shape
# Out:
# (45, 9)

# %%
df.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewername', 'helpful', 'reviewerText',
#        'overallRating', 'Summary', 'UnixreviewTime', 'reviewTime'],
#       dtype='object')

# %%
#creating subsets
df1 = df[['reviewerID','helpful','overallRating']].iloc[:11]
df1
# Out:
#          reviewerID  helpful  overallRating
# 0    A2SUAM1J3GNN3B        2            4.0
# 1    A2SUAN1J3GNN0C        3            3.0
# 2    A2SUAN1J3GNN7B        3            2.5
# 3    A5SUAN1J3GNN9B        3            2.2
# 4    A1SUAM1J3GNN3B        3            3.0
# 5   BA2345WERSDFRER        3            3.0
# 6   CADERVG3450EREW        3            3.0
# 7   ASDF345671QWERT        3            3.0
# 8     MNHJ879WERFGH        2            3.0
# 9    1234ZSDFREQWEG        2            5.0
# 10   9345GHIKLFLLED        2            4.0

# %%
df2 = df[['reviewerID','helpful','overallRating']].iloc[11:21]
df2
# Out:
#          reviewerID  helpful  overallRating
# 11              NaN        2            4.0
# 12   HGKIUYE345SFDG        2            4.0
# 13  NIKRT2398701222        2            3.0
# 14   MAHI2348900122        2            3.0
# 15   LIHJKD87634O21        2            3.0
# 16  SISISWER4657893        2            3.0
# 17   MIKI23412341QW        2            2.0
# 18   AAAJI37DFG378I        2            2.0
# 19   FAJI234GAJI987        2            2.0
# 20    VABI9876ERTT1        2            2.0

# %%
df3 = df[['reviewerID','helpful','overallRating']].iloc[21:31]
df3
# Out:
#          reviewerID  helpful  overallRating
# 21   NIKI12NIKI1231        2            4.0
# 22   MIKISDF1232XAD        2            4.0
# 23     GHAU8768QWER        2            4.0
# 24   NIKI12NIKI1231        3            4.0
# 25   MIKISDF1232XAD        3            4.0
# 26     GHAU8768QWER        3            4.0
# 27  BA2345WERSDFRER        3            4.0
# 28  CADERVG3450EREW        3            4.0
# 29  ASDF345671QWERT        3            4.0
# 30    MNHJ879WERFGH        3            4.0

# %%
merging = pd.concat([df1,df2,df3])
merging
# Out:
#          reviewerID  helpful  overallRating
# 0    A2SUAM1J3GNN3B        2            4.0
# 1    A2SUAN1J3GNN0C        3            3.0
# 2    A2SUAN1J3GNN7B        3            2.5
# 3    A5SUAN1J3GNN9B        3            2.2
# 4    A1SUAM1J3GNN3B        3            3.0
# 5   BA2345WERSDFRER        3            3.0
# 6   CADERVG3450EREW        3            3.0
# 7   ASDF345671QWERT        3            3.0
# 8     MNHJ879WERFGH        2            3.0
# 9    1234ZSDFREQWEG        2            5.0
# 10   9345GHIKLFLLED        2            4.0
# 11              NaN        2            4.0
# 12   HGKIUYE345SFDG        2            4.0
# 13  NIKRT2398701222        2            3.0
# 14   MAHI2348900122        2            3.0
# 15   LIHJKD87634O21        2            3.0
# 16  SISISWER4657893        2            3.0
# 17   MIKI23412341QW        2            2.0
# 18   AAAJI37DFG378I        2            2.0
# 19   FAJI234GAJI987        2            2.0
# 20    VABI9876ERTT1        2            2.0
# 21   NIKI12NIKI1231        2            4.0
# 22   MIKISDF1232XAD        2            4.0
# 23     GHAU8768QWER        2            4.0
# 24   NIKI12NIKI1231        3            4.0
# 25   MIKISDF1232XAD        3            4.0
# 26     GHAU8768QWER        3            4.0
# 27  BA2345WERSDFRER        3            4.0
# 28  CADERVG3450EREW        3            4.0
# 29  ASDF345671QWERT        3            4.0
# 30    MNHJ879WERFGH        3            4.0

# %%
sorting = merging.sort_values('overallRating', ascending=False)
sorting
# Out:
#          reviewerID  helpful  overallRating
# 9    1234ZSDFREQWEG        2            5.0
# 0    A2SUAM1J3GNN3B        2            4.0
# 12   HGKIUYE345SFDG        2            4.0
# 29  ASDF345671QWERT        3            4.0
# 28  CADERVG3450EREW        3            4.0
# 27  BA2345WERSDFRER        3            4.0
# 26     GHAU8768QWER        3            4.0
# 25   MIKISDF1232XAD        3            4.0
# 24   NIKI12NIKI1231        3            4.0
# 23     GHAU8768QWER        2            4.0
# 22   MIKISDF1232XAD        2            4.0
# 21   NIKI12NIKI1231        2            4.0
# 30    MNHJ879WERFGH        3            4.0
# 10   9345GHIKLFLLED        2            4.0
# 11              NaN        2            4.0
# 4    A1SUAM1J3GNN3B        3            3.0
# 5   BA2345WERSDFRER        3            3.0
# 6   CADERVG3450EREW        3            3.0
# 7   ASDF345671QWERT        3            3.0
# 8     MNHJ879WERFGH        2            3.0
# 14   MAHI2348900122        2            3.0
# 13  NIKRT2398701222        2            3.0
# 16  SISISWER4657893        2            3.0
# 1    A2SUAN1J3GNN0C        3            3.0
# 15   LIHJKD87634O21        2            3.0
# 2    A2SUAN1J3GNN7B        3            2.5
# 3    A5SUAN1J3GNN9B        3            2.2
# 20    VABI9876ERTT1        2            2.0
# 19   FAJI234GAJI987        2            2.0
# 18   AAAJI37DFG378I        2            2.0
# 17   MIKI23412341QW        2            2.0

# %%
df.transpose()
# Out:
#                                                                0   \
# reviewerID                                         A2SUAM1J3GNN3B
# asin                                                        23456
# reviewername                                                SNEHA
# helpful                                                         2
# reviewerText    I bought this for my husband who plays the pia...
# overallRating                                                   4
# Summary                                               SUBWAY SURF
# UnixreviewTime                                                NaN
# reviewTime                                                    NaN
#
#                                1                2                3   \
# reviewerID         A2SUAN1J3GNN0C   A2SUAN1J3GNN7B   A5SUAN1J3GNN9B
# asin                       879877            23456            67578
# reviewername              KARTHII         SHASHANK            NITIN
# helpful                         3                3                3
# reviewerText    good book to read        high cost  good useof book
# overallRating                   3              2.5              2.2
# Summary                    PILOT   DRIVE IN HEAVEN    SPORTS HEAVEN
# UnixreviewTime                NaN              NaN              NaN
# reviewTime                    NaN              NaN              NaN
#
#                                      4   \
# reviewerID               A1SUAM1J3GNN3B
# asin                                123
# reviewername                    PRANOTI
# helpful                               3
# reviewerText    I m happy with the book
# overallRating                         3
# Summary                HEAVEN OF PEARLS
# UnixreviewTime                      NaN
# reviewTime                          NaN
#
#                                                     5                6   \
# reviewerID                             BA2345WERSDFRER  CADERVG3450EREW
# asin                                            236789              NaN
# reviewername                                   SHALINI           SNEHAL
# helpful                                              3                3
# reviewerText    im not happy with the delay of product    delay in book
# overallRating                                        3                3
# Summary                                      GODS GIFT      GODESS LIFE
# UnixreviewTime                                     NaN              NaN
# reviewTime                                         NaN              NaN
#
#                              7   \
# reviewerID      ASDF345671QWERT
# asin                     224442
# reviewername             SHIKHA
# helpful                       3
# reviewerText     Wonderful book
# overallRating                 3
# Summary             LIFE OF PIE
# UnixreviewTime              NaN
# reviewTime                  NaN
#
#                                                                8   \
# reviewerID                                          MNHJ879WERFGH
# asin                                                        98767
# reviewername                                               AKSHAY
# helpful                                                         2
# reviewerText    The music is at times hard to read because we ...
# overallRating                                                   3
# Summary                                     INDIA A MASSIVE POWER
# UnixreviewTime                                                NaN
# reviewTime                                                    NaN
#
#                             9       ...                       35  \
# reviewerID      1234ZSDFREQWEG      ...          NIKRT2398701222
# asin                     78761      ...                    21221
# reviewername            SATISH      ...                     NEIL
# helpful                      2      ...                        3
# reviewerText       many errors      ...                 8.78E+21
# overallRating                5      ...                        3
# Summary           DATA IS DATA      ...       good buy for money
# UnixreviewTime             NaN      ...                      NaN
# reviewTime                 NaN      ...                      NaN
#
#                             36                37               38  \
# reviewerID      MAHI2348900122    LIHJKD87634O21  SISISWER4657893
# asin                     22245               678              111
# reviewername           KANGANA             KHANN            RIYAA
# helpful                      3                 3                3
# reviewerText             67667           3434567             098O
# overallRating                2                 2                2
# Summary          money is dis   stare the raeder  reader is giood
# UnixreviewTime             NaN               NaN              NaN
# reviewTime                 NaN               NaN              NaN
#
#                           39            40         41           42  \
# reviewerID      8786112GHAUI   67FDASAA123  ASWER1234   QWCVFED123
# asin                     223          2312       1222        11111
# reviewername             NaN       NANAJJI     PREETI        DHONI
# helpful                    3             3          2            2
# reviewerText       GOOD LUCK   BYE MY LOVE    LOVE U    HELLO DEAR
# overallRating              2             4          4            4
# Summary              faskjas  HELL OF HELL       DEAA  DEAR TO ALL
# UnixreviewTime           NaN           NaN        NaN          NaN
# reviewTime               NaN           NaN        NaN          NaN
#
#                                    43            44
# reviewerID                123LKIUHNFG  987DFHGJI657
# asin                             9800           NaN
# reviewername                     MAHI           DDE
# helpful                             2             2
# reviewerText    DAER PLEASE READ BOOK          BOOK
# overallRating                       4             4
# Summary                       MOTHER   WINE OF WINE
# UnixreviewTime                    NaN           NaN
# reviewTime                        NaN           NaN
#
# [9 rows x 45 columns]

# %%
merging.transpose()
# Out:
#                            0               1               2               3   \
# reviewerID     A2SUAM1J3GNN3B  A2SUAN1J3GNN0C  A2SUAN1J3GNN7B  A5SUAN1J3GNN9B
# helpful                     2               3               3               3
# overallRating               4               3             2.5             2.2
#
#                            4                5                6   \
# reviewerID     A1SUAM1J3GNN3B  BA2345WERSDFRER  CADERVG3450EREW
# helpful                     3                3                3
# overallRating               3                3                3
#
#                             7              8               9       ...        \
# reviewerID     ASDF345671QWERT  MNHJ879WERFGH  1234ZSDFREQWEG      ...
# helpful                      3              2               2      ...
# overallRating                3              3               5      ...
#
#                            21              22            23              24  \
# reviewerID     NIKI12NIKI1231  MIKISDF1232XAD  GHAU8768QWER  NIKI12NIKI1231
# helpful                     2               2             2               3
# overallRating               4               4             4               4
#
#                            25            26               27               28  \
# reviewerID     MIKISDF1232XAD  GHAU8768QWER  BA2345WERSDFRER  CADERVG3450EREW
# helpful                     3             3                3                3
# overallRating               4             4                4                4
#
#                             29             30
# reviewerID     ASDF345671QWERT  MNHJ879WERFGH
# helpful                      3              3
# overallRating                4              4
#
# [3 rows x 31 columns]

# %%
sorting.shape
# Out:
# (31, 3)

# %%
array = sorting.values
reshaped_array = np.reshape(array, (3, 31))
