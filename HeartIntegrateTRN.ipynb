# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
heart = pd.read_csv('heart.csv')

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
# age         1025 non-null int64
# sex         1025 non-null int64
# cp          1025 non-null int64
# trestbps    1025 non-null int64
# chol        1025 non-null int64
# fbs         1025 non-null int64
# restecg     1025 non-null int64
# thalach     1025 non-null int64
# exang       1025 non-null int64
# oldpeak     1025 non-null float64
# slope       1025 non-null int64
# ca          1025 non-null int64
# thal        1025 non-null int64
# target      1025 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 112.1 KB

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart.shape
# Out:
# (1025, 14)

# %%
heart.fillna(heart.mode().iloc[0], inplace=True)

# %%
heart.drop_duplicates(inplace=True)

# %%
heart.shape
# Out:
# (302, 14)

# %%
print("Data Cleaning Done")
# Out:
# Data Cleaning Done

# %%
heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df1 = heart[['age', 'sex', 'cp', 'trestbps']]
df2 = heart[['trestbps', 'chol', 'fbs', 'restecg']]

# %%
df1,df2
# Out:
# (     age  sex  cp  trestbps
#  0     52    1   0       125
#  1     53    1   0       140
#  2     70    1   0       145
#  3     61    1   0       148
#  4     62    0   0       138
#  5     58    0   0       100
#  6     58    1   0       114
#  7     55    1   0       160
#  8     46    1   0       120
#  9     54    1   0       122
#  10    71    0   0       112
#  11    43    0   0       132
#  12    34    0   1       118
#  13    51    1   0       140
#  14    52    1   0       128
#  16    51    0   2       140
#  17    54    1   0       124
#  18    50    0   1       120
#  19    58    1   2       140
#  20    60    1   2       140
#  21    67    0   0       106
#  22    45    1   0       104
#  23    63    0   2       135
#  24    42    0   2       120
#  25    61    0   0       145
#  26    44    1   2       130
#  27    58    0   1       136
#  28    56    1   2       130
#  29    55    0   0       180
#  30    44    1   0       120
#  ..   ...  ...  ..       ...
# ...

# %%
data = pd.merge(df1,df2,on='trestbps',how='inner')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg
# 0   52    1   0       125   212    0        1
# 1   52    1   0       125   213    0        0
# 2   52    1   0       125   249    1        0
# 3   52    1   0       125   300    0        0
# 4   52    1   0       125   304    0        0

# %%
#Transformation
heart = heart.astype(str)

# %%
encoder = LabelEncoder()
for col in heart.select_dtypes(include=['object']):
    heart[col] = encoder.fit_transform(heart[col])

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   18    1   0        17    43    0        1       60      0       10      2
# 1   19    1   0        27    34    1        0       47      1       29      0
# 2   36    1   0        30    12    0        1       18      1       25      0
# 3   27    1   0        32    34    0        1       53      0        0      2
# 4   28    0   0        26   116    1        1        2      0       18      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#model building

x = heart.drop(columns=['age'])
y = heart['cp']
y = y.round().astype(int)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 2, 0, 2, 2, 0, 0, 2, 0, 2, 0, 0, 2, 1, 0, 0, 0, 1, 0, 0, 1, 0,
#        3, 2, 0, 0, 2, 2, 0, 0, 1, 1, 1, 0, 1, 2, 0, 2, 0, 0, 0, 0, 0, 3,
#        0, 0, 1, 0, 3, 2, 0, 0, 0, 0, 1, 0, 1, 2, 0, 0, 0], dtype=int32)

# %%
#accuracy
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9508196721311475
